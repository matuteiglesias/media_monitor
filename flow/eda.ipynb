# %%
import pandas as pd

# %%
import pandas as pd

# Path to your heap file
path = "/home/matias/dev/my-agents/Cities/gpt_chats/flows/gpt_chats2/outputs_heap.jsonl"

# Load the JSONL file
df = pd.read_json(path, lines=True)

# Show the first few rows
display(df.head())
# Out:
#                                                title  \
# 0          Long-term Strategic Relevance vs. Discard
# 1                        Plan for the Impossible MVP
# 2  Dual-Layered Organizational System for Sustain...
# 3                                               None
# 4  Plan for the Impossible: Voice AI Romantic Cha...
#
#                                              summary  has_codeblock  \
# 0  Breakdown of strategic work worth keeping and ...          False
# 1  A detailed roadmap for developing a personaliz...           True
# 2  The message outlines a dual-layered organizati...           True
# 3                                               None          False
# 4  A comprehensive launch plan for a minimum lova...           True
#
#    has_table   format_type            response_type  \
# 0      False       summary       strategic analysis
# 1       True  project plan         project planning
# 2      False         guide  organizational strategy
# ...

# %%
df.to_csv('./test_output_data.csv')

# %%
for col in df.columns:
    display(df[col].value_counts())
# Out:
# title
# Using pipreqs for requirements generation              2
# Agent Onboarding Prompt for Hugging Face Spaces        2
# General LLM Tool Agent Pattern                         1
# Debugging FastAPI Query Issues                         1
# FastAPI Endpoint Debugging                             1
#                                                       ..
# Gradio State Management and Fixes                      1
# Gradio UI Integration for Tech Support Agent           1
# Simplified ChatSupportAgent Implementation             1
# Explanation of Step-by-Step Logic in Agent Workflow    1
# Vision for Workflow Architecture                       1
# Name: count, Length: 261, dtype: int64
# summary
# Breakdown of strategic work worth keeping and non-strategic items to discard, focusing on long-term goals and actionable insights.                                                                                                                                   1
# ...

# %%
pd.options.display.max_colwidth = 999
pd.options.display.max_rows = 120

# %%
df.count()
# Out:
# title                    263
# summary                  263
# has_codeblock            283
# has_table                283
# format_type              263
# response_type            263
# domain                   263
# medium                   263
# perspective              263
# tech_level               263
# reflective_worthy        283
# code_snippet_reusable    283
# seeds_blog               283
# suggests_product         283
# kwds                     283
# suggested_actions        262
# dtype: int64

# %%
df
# Out:
#                                                            title  \
# 0                      Long-term Strategic Relevance vs. Discard
# 1                                    Plan for the Impossible MVP
# 2    Dual-Layered Organizational System for Sustainable Velocity
# 3                                                           None
# 4             Plan for the Impossible: Voice AI Romantic Chatbot
# ..                                                           ...
# 278                                   Cerebrum Agent Wiring Demo
# 279                   Minimal Working Example for PromptFlow DAG
# 280                            Unified Cerebrum Ecosystem Mockup
# 281                   Next Steps for Developer-Friendly Platform
# 282                             Vision for Workflow Architecture
#
# ...

# %%
df.loc[df.suggests_product][['summary', 'suggested_actions']]
# Out:
#                                                                                                                                                                                                                                                                summary  \
# 1                                                                      A detailed roadmap for developing a personalized voice generation tool for YouTubers and marketers, including phases for script reading, user voice upload, AI scriptwriting, and monetization.
# 2                               The message outlines a dual-layered organizational system to enhance sustainable velocity by auto-journaling past work and structuring technical planning for app development, emphasizing accessibility for both humans and machines.
# ...
